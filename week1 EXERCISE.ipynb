# %%
# imports

import os
import json
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from scraper import fetch_website_links, fetch_website_contents
from openai import OpenAI

# %%
# constants
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')
MODEL = 'gemini-2.5-pro'
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
openai = OpenAI(base_url=GEMINI_BASE_URL)

# %%
# set up environment
system_prompt = """
you are a coding tutor explaining to 12 year old kids,
use only coding experties to answer the given question logically with example and point wise
"""

# %%
# here is the question; type over this to ask something new
def ai_tutor(question):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role":'system',"content":system_prompt},
            {"role":'user',"content":question}
        ],
        stream=True,
    )
    response = ''
    display_handle= display(Markdown(""),display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ""
        update_display(Markdown(response),display_id=display_handle.display_id)

# %%
# Get gpt-4o-mini to answer, with streaming
question = input("Ask your doubt: ")
ai_tutor(question)
# Out:
# Awesome question! Let's get into it.
#
# Imagine your mom asks you to bring in 5 logs for the fireplace.
#
# Without a loop, your brain's code would look like this:
#
# 1.  Go outside.
# 2.  Pick up one log.
# 3.  Bring it inside.
# 4.  Go outside.
# 5.  Pick up one log.
# 6.  Bring it inside.
# 7.  Go outside.
# 8.  Pick up one log.
# 9.  Bring it inside.
# 10. Go outside.
# 11. Pick up one log.
# 12. Bring it inside.
# 13. Go outside.
# 14. Pick up one log.
# 15. Bring it inside.
#
# Phew! That's a lot of repeating yourself. As a coder, you want to be smart and a little bit lazy. You don't want to write the same instructions over and over again.
#
# This is where a **loop** comes in!
#
# ### What is a Loop?
#
# A loop is a way to tell the computer to **repeat a set of instructions** over and over again until a certain condition is met.
#
# It's like telling the computer: "Do this thing **for** 5 times" or "Keep doing this thing **while** the light is green".
#
# ...
